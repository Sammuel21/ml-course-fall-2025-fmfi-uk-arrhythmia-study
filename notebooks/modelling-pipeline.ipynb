# %% [markdown]
# ## Modeling Pipeline
#
# This notebook focuses on the development of project ML/DL models - focus on modelling pipeline setup & **baseline** models.

# %% [markdown]
# ### Research Questions:
#
# 1. Build baseline ML and DL models
# 2. Build optimized ML and DL models
# 3. Are optimized models better -> how much?
# 4. Is baseline DL model better than optimized ML model?
# 5. Knowledge distillation:
#     - is distilled ML model better than optmized ML model?
#     - is distilled ML model better than baseline DL model?

# %%
import os
import sys

sys.dont_write_bytecode = True
root_dir = os.path.abspath(os.pardir)
if root_dir not in sys.path:
    sys.path.append(root_dir)

# %%
import json
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from configs.constants import *

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler, PolynomialFeatures
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.decomposition import PCA
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.base import clone

# %%
from sklearn.metrics import accuracy_score, hamming_loss
from scripts.scoring import *

# %%
data_dir = '../data/preprocessing/ML/'
meta_df_file = '../data/results/complete_metadata_mapping_2.csv'

train_0_file = 'meta_df_preprocess_X_train_0.csv'
test_0_file = 'meta_df_preprocess_X_test_0.csv'
train_1_file = 'meta_df_preprocess_X_train_1.csv'
test_1_file = 'meta_df_preprocess_X_test_1.csv'

# %% [markdown]
# ### Models

# %% [markdown]
# train test split indices

# %%
meta_df = pd.read_csv(meta_df_file)
meta_df['dx_codes'] = meta_df['dx_codes'].map(json.loads)

# %%
X = meta_df.drop('dx_codes', axis=1)
y = meta_df['dx_codes']

_X_train, _X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, random_state=TTS_SEED)

_X_train = _X_train.reset_index(drop=True)
_X_test = _X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %% [markdown]
# loading train and test data

# %%
X_train_0 = pd.read_csv(os.path.join(data_dir, train_0_file))
X_test_0 = pd.read_csv(os.path.join(data_dir, test_0_file))
X_train_1 = pd.read_csv(os.path.join(data_dir, train_1_file))
X_test_1 = pd.read_csv(os.path.join(data_dir, test_1_file))

y_train_saved = pd.read_csv(os.path.join(data_dir, 'y_train.csv'))['dx_codes'].map(json.loads)
y_test_saved = pd.read_csv(os.path.join(data_dir, 'y_test.csv'))['dx_codes'].map(json.loads)
# Out:
# C:\Users\samue\AppData\Local\Temp\ipykernel_26608\92334015.py:1: DtypeWarning: Columns (114) have mixed types. Specify dtype option on import or set low_memory=False.
#   X_train_0 = pd.read_csv(os.path.join(data_dir, train_0_file))
# C:\Users\samue\AppData\Local\Temp\ipykernel_26608\92334015.py:3: DtypeWarning: Columns (114) have mixed types. Specify dtype option on import or set low_memory=False.
#   X_train_1 = pd.read_csv(os.path.join(data_dir, train_1_file))

# %% [markdown]
# equivalence test

# %%
assert all(y_train_saved.map(tuple) == y_train.map(tuple))
assert all(y_test_saved.map(tuple) == y_test.map(tuple))

# %% [markdown]
# dropping error rows from X, y

# %%
bad_index_train = X_train_0.dropna(subset='error').index

# %%
X_train_0 = X_train_0.drop(bad_index_train, errors='ignore')
X_train_1 = X_train_1.drop(bad_index_train, errors='ignore')

y_train = y_train.drop(bad_index_train, errors='ignore')

# %%
X_train_0 = X_train_0.reset_index(drop=True)
X_train_1 = X_train_1.reset_index(drop=True)
X_test_0 = X_test_0.reset_index(drop=True)
X_test_1 = X_test_1.reset_index(drop=True)

# %% [markdown]
# **model preprocessing**

# %% [markdown]
# remove metadata features

# %%
meta_features = ['record_id', 'filter_mode', 'beat_lead', 'error', 'fs', 'n_leads', 'n_samples']

# %%
X_train_0 = X_train_0.drop(meta_features, axis=1, errors='ignore')
X_train_1 = X_train_1.drop(meta_features, axis=1, errors='ignore')
X_test_0 = X_test_0.drop(meta_features, axis=1, errors='ignore')
X_test_1 = X_test_1.drop(meta_features, axis=1, errors='ignore')

# %% [markdown]
# train/validation split:
# - we use test split only at the final mode eval

# %%
train_idx, val_idx = train_test_split(
    np.arange(len(y_train)),
    test_size=VAL_SIZE,
    random_state=TTS_SEED,
)

# Raw features
X_tr_0 = X_train_0.iloc[train_idx].reset_index(drop=True)
X_val_0 = X_train_0.iloc[val_idx].reset_index(drop=True)

# Bandpass features
X_tr_1 = X_train_1.iloc[train_idx].reset_index(drop=True)
X_val_1 = X_train_1.iloc[val_idx].reset_index(drop=True)

# Targets
y_tr = y_train.iloc[train_idx].reset_index(drop=True)
y_val = y_train.iloc[val_idx].reset_index(drop=True)

# %% [markdown]
# label encoding

# %%
mlb = MultiLabelBinarizer()
y_tr_bin = mlb.fit_transform(y_tr)
y_val_bin = mlb.transform(y_val)
y_test_bin = mlb.transform(y_test)

# %% [markdown]
# final preprocessing (using pipeline fit)

# %%
nominal_columns = ['sex']
numerical_columns = X_train_0.select_dtypes(exclude='object').columns

# %%
categorical_pipe = Pipeline([
    ('nulls', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

numerical_pipe = Pipeline([
    ('nulls', SimpleImputer()),
    ('scale', StandardScaler()),
    #('poly', PolynomialFeatures(degree=2)),
    #('pca', PCA(n_components=0.99))
])

# %%
ct = ColumnTransformer(
    transformers=[
        ('numerical', numerical_pipe, numerical_columns),
        ('categorical', categorical_pipe, nominal_columns)
    ],
    remainder='passthrough'
)

# %% [markdown]
# #### **ML**

# %% [markdown]
# baseline model:
# 1. Logistic regression
# 2. SVM

# %%
n_jobs = 10
save_ = False

# %%
clf = OneVsRestClassifier(LogisticRegression(max_iter=2000), n_jobs=n_jobs)

base_model = Pipeline([
    ("preprocess", ct),
    ("clf", clf)
])

# Raw
model_raw = clone(base_model)
model_raw.fit(X_tr_0, y_tr_bin)
val_logits_raw = model_raw.decision_function(X_val_0)
lr_res_raw = score_overall_and_rc(y_val_bin, val_logits_raw, mlb, split_name="val-raw")

# Bandpass
model_filt = clone(base_model)
model_filt.fit(X_tr_1, y_tr_bin)
val_logits_filt = model_filt.decision_function(X_val_1)
lr_res_bandpass = score_overall_and_rc(y_val_bin, val_logits_filt, mlb, split_name="val-filt")

if save_:
    joblib.dump(model_raw, '../models/lr-baseline-raw.joblib')
    joblib.dump(model_filt, '../models/lr-baseline-filt.joblib')

pass
# Out:
# [val-raw] overall: {'f1_micro': np.float64(0.5475216751185997), 'f1_macro': np.float64(0.0975296181685033), 'f1_samples': np.float64(0.5919852839636304), 'hamming_loss': 0.014481068855754732, 'auroc_micro': np.float64(0.9593152132080986), 'auroc_macro': np.float64(0.8315732082349065), 'ap_micro': np.float64(0.5913927084082796), 'ap_macro': np.float64(0.18167702515884385)}
# [val-raw] conditions: {'f1_micro': np.float64(0.19607843137254902), 'f1_macro': np.float64(0.06218994171108674), 'f1_samples': np.float64(0.06636599402347433), 'hamming_loss': 0.010809195725534309, 'auroc_micro': np.float64(0.9452502687444373), 'auroc_macro': np.float64(0.834190032181299), 'ap_micro': np.float64(0.3190265845714747), 'ap_macro': np.float64(0.1460152977607099)}
# [val-raw] rhythm: {'f1_micro': np.float64(0.7587742273441592), 'f1_macro': np.float64(0.3943829004108023), 'f1_samples': np.float64(0.6942421259842518), 'hamming_loss': 0.045324803149606296, 'auroc_micro': np.float64(0.9616851610586743), 'auroc_macro': np.float64(0.8129937582155209), 'ap_micro': np.float64(0.7831484070472056), 'ap_macro': np.float64(0.4348752896855944), 'used_argmax_multiclass': False}
# [val-filt] overall: {'f1_micro': np.float64(0.5562999434982646), 'f1_macro': np.float64(0.10305466442333955), 'f1_samples': np.float64(0.6032174245264796), 'hamming_loss': 0.014389449656558887, 'auroc_micro': np.float64(0.9616034570693572), 'auroc_macro': np.float64(0.8434788837318473), 'ap_micro': np.float64(0.5976771164096262), 'ap_macro': np.float64(0.18721377134489167)}
# [val-filt] conditions: {'f1_micro': np.float64(0.22015634903866468), 'f1_macro': np.float64(0.0690882379166619), 'f1_samples': np.float64(0.07819432727159105), 'hamming_loss': 0.010812125046869141, 'auroc_micro': np.float64(0.947911197567132), 'auroc_macro': np.float64(0.8412293264653626), 'ap_micro': np.float64(0.32587979376769244), 'ap_macro': np.float64(0.15206890080195143)}
# [val-filt] rhythm: {'f1_micro': np.float64(0.7641065830721003), 'f1_macro': np.float64(0.38837264707943164), 'f1_samples': np.float64(0.7009924540682414), 'hamming_loss': 0.04443897637795276, 'auroc_micro': np.float64(0.963352369383374), 'auroc_macro': np.float64(0.8594507403238894), 'ap_micro': np.float64(0.7888407597061717), 'ap_macro': np.float64(0.43674235219976765), 'used_argmax_multiclass': False}

# %% [markdown]
# single label classification subset
#
# - we extract the single label (rhytm) part and evaluate
# - we evaluate the multilabel of the conditions as well

# %% [markdown]
# SVM
#
# - logistic regression might be dependent on polynomial features
# - we use RBF SVM in order to better capture complex relationships
# - NOTE: high space complexity -> we will downsample

# %%
# SVM
frac = 0.15
save_ = False

svm_clf = OneVsRestClassifier(SVC(kernel="rbf", C=10), n_jobs=n_jobs)
svm_base = Pipeline([
    ("preprocess", ct),
    ("clf", svm_clf),
])

# ----- Raw -----
idx_raw = X_tr_0.sample(frac=frac, random_state=TTS_SEED).index
X_tr_raw_s = X_tr_0.loc[idx_raw]
y_tr_raw_s = y_tr_bin[idx_raw]

svm_raw = clone(svm_base)
svm_raw.fit(X_tr_raw_s, y_tr_raw_s)
val_logits_raw = svm_raw.decision_function(X_val_0)
score_overall_and_rc(y_val_bin, val_logits_raw, mlb, split_name="svm-val-raw")

# ----- Bandpass -----
idx_filt = X_tr_1.sample(frac=frac, random_state=TTS_SEED).index
X_tr_filt_s = X_tr_1.loc[idx_filt]
y_tr_filt_s = y_tr_bin[idx_filt]

svm_filt = clone(svm_base)
svm_filt.fit(X_tr_filt_s, y_tr_filt_s)
val_logits_filt = svm_filt.decision_function(X_val_1)
score_overall_and_rc(y_val_bin, val_logits_filt, mlb, split_name="svm-val-filt")

if save_:
    joblib.dump(svm_raw, '../models/svm-baseline-raw.joblib')
    joblib.dump(svm_filt, '../models/svm-baseline-filt.joblib')

pass
# Out:
# [svm-val-raw] overall: {'f1_micro': np.float64(0.12489289149252426), 'f1_macro': np.float64(0.09960835718340941), 'f1_samples': np.float64(0.12279249926212595), 'hamming_loss': 0.13099713101021948, 'auroc_micro': np.float64(0.8780046539642714), 'auroc_macro': np.float64(0.7512904290338757), 'ap_micro': np.float64(0.46313835830951433), 'ap_macro': np.float64(0.15978435631328622)}
# [svm-val-raw] conditions: {'f1_micro': np.float64(0.027043071037530505), 'f1_macro': np.float64(0.06452243194413466), 'f1_samples': np.float64(0.022312995262330663), 'hamming_loss': 0.1296312570303712, 'auroc_micro': np.float64(0.8096161073102175), 'auroc_macro': np.float64(0.7382954993339191), 'ap_micro': np.float64(0.14725768493472047), 'ap_macro': np.float64(0.12053384599086965)}
# [svm-val-raw] rhythm: {'f1_micro': np.float64(0.5052127841394634), 'f1_macro': np.float64(0.39433012919331734), 'f1_samples': np.float64(0.478387467191601), 'hamming_loss': 0.14247047244094488, 'auroc_micro': np.float64(0.9328179265598954), 'auroc_macro': np.float64(0.8435544299035669), 'ap_micro': np.float64(0.7661187376382605), 'ap_macro': np.float64(0.4384629796024435), 'used_argmax_multiclass': False}
# [svm-val-filt] overall: {'f1_micro': np.float64(0.12759076366671304), 'f1_macro': np.float64(0.105139913387975), 'f1_samples': np.float64(0.1255013418052905), 'hamming_loss': 0.1313400485843525, 'auroc_micro': np.float64(0.8837693066660715), 'auroc_macro': np.float64(0.7629111508833469), 'ap_micro': np.float64(0.47207641925594807), 'ap_macro': np.float64(0.159507740377089)}
# [svm-val-filt] conditions: {'f1_micro': np.float64(0.031198793996198466), 'f1_macro': np.float64(0.07101564267886092), 'f1_samples': np.float64(0.025878667511325934), 'hamming_loss': 0.12989489595050618, 'auroc_micro': np.float64(0.820656616993202), 'auroc_macro': np.float64(0.7580412658567321), 'ap_micro': np.float64(0.16464495145727873), 'ap_macro': np.float64(0.12081995935782333)}
# [svm-val-filt] rhythm: {'f1_micro': np.float64(0.5033642790222298), 'f1_macro': np.float64(0.39178378734453345), 'f1_samples': np.float64(0.4770341207349082), 'hamming_loss': 0.14347933070866142, 'auroc_micro': np.float64(0.9329113512452402), 'auroc_macro': np.float64(0.7974873345723117), 'ap_micro': np.float64(0.7653682905949436), 'ap_macro': np.float64(0.4341909856138752), 'used_argmax_multiclass': False}

# %% [markdown]
# **XGBoost Optimized** (ensemble model)
#
# - ensemble model
# - utilizing CV strategies
# - transformation optimization
# - hyperparam optimization

# %%
import xgboost as xgb

# %%
n_estimators = 600
learning_rate = 0.05
max_depth = 4
subsample = 0.8
colsample_bytree = 0.8
reg_lambda = 1

n_jobs = 10
save_ = True

# %%
xgb_params = {
    "objective": "binary:logistic",
    "tree_method": "hist",
    "device": "cuda",
    "n_estimators": n_estimators,
    "learning_rate": learning_rate,
    "max_depth": max_depth,
    "subsample": subsample,
    "colsample_bytree": colsample_bytree,
    "reg_lambda": reg_lambda,
    "n_jobs": n_jobs,
    "random_state": TTS_SEED,
}

# %%
xgb_base = xgb.XGBClassifier(**xgb_params)

# %%
model = OneVsRestClassifier(xgb_base, n_jobs=1)

xgb_pipeline = Pipeline([
    ('preprocess', ct),
    ('model', model)
])

# %%
save_ = False

# %%
# raw
xgb_raw = clone(xgb_pipeline)
xgb_raw.fit(X_tr_0, y_tr_bin)

P_val_raw = xgb_raw.predict_proba(X_val_0)
xgb_res_raw = score_overall_and_rc(
    y_val_bin, P_val_raw, mlb,
    split_name="xgb-ovr-val-raw",
    threshold=0.5,
    inputs_are_probs=True,
)

# bandpass
xgb_filt = clone(xgb_pipeline)
xgb_filt.fit(X_tr_1, y_tr_bin)

P_val_filt = xgb_filt.predict_proba(X_val_1)
xgb_res_filt = score_overall_and_rc(
    y_val_bin, P_val_filt, mlb,
    split_name="xgb-ovr-val-filt",
    threshold=0.5,
    inputs_are_probs=True,
)

if save_:
    joblib.dump(xgb_raw, '../models/xgb/xgb-baseline-raw.joblib')
    joblib.dump(xgb_filt, '../models/xgb/xgb-baseline-filt.joblib')
# Out:
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:774: UserWarning: [14:46:26] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\common\error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# [xgb-ovr-val-raw] overall: {'f1_micro': np.float64(0.6618153963998468), 'f1_macro': np.float64(0.14465389761258513), 'f1_samples': np.float64(0.7247915415730377), 'hamming_loss': 0.011557107555704473, 'auroc_micro': np.float64(0.97701716761247), 'auroc_macro': np.float64(0.8740862485649855), 'ap_micro': np.float64(0.7539490506980515), 'ap_macro': np.float64(0.2507852457167594)}
# [xgb-ovr-val-raw] conditions: {'f1_micro': np.float64(0.3472330475448168), 'f1_macro': np.float64(0.10349082278569197), 'f1_samples': np.float64(0.14486205914601583), 'hamming_loss': 0.009813226471691038, 'auroc_micro': np.float64(0.9613893588079176), 'auroc_macro': np.float64(0.8710263973175587), 'ap_micro': np.float64(0.4510165641647809), 'ap_macro': np.float64(0.20955080688598782)}
# [xgb-ovr-val-raw] rhythm: {'f1_micro': np.float64(0.8655812192351382), 'f1_macro': np.float64(0.4904237261584875), 'f1_samples': np.float64(0.8303395669291339), 'hamming_loss': 0.02620570866141732, 'auroc_micro': np.float64(0.9899163184479441), 'auroc_macro': np.float64(0.8958111924217173), 'ap_micro': np.float64(0.9426744921798437), 'ap_macro': np.float64(0.5435497614152381), 'used_argmax_multiclass': False}
# [xgb-ovr-val-filt] overall: {'f1_micro': np.float64(0.6627363907817165), 'f1_macro': np.float64(0.146065973908276), 'f1_samples': np.float64(0.7269090120837168), 'hamming_loss': 0.011530930641648517, 'auroc_micro': np.float64(0.9771409769345207), 'auroc_macro': np.float64(0.8888175621443961), 'ap_micro': np.float64(0.750057881667352), 'ap_macro': np.float64(0.25438224043396623)}
# [xgb-ovr-val-filt] conditions: {'f1_micro': np.float64(0.3519845111326234), 'f1_macro': np.float64(0.10505779641510726), 'f1_samples': np.float64(0.14985841613548306), 'hamming_loss': 0.009804438507686539, 'auroc_micro': np.float64(0.9614629851176753), 'auroc_macro': np.float64(0.8865608050176581), 'ap_micro': np.float64(0.44279749025544957), 'ap_macro': np.float64(0.21145409116318303)}
# [xgb-ovr-val-filt] rhythm: {'f1_micro': np.float64(0.8660081053698075), 'f1_macro': np.float64(0.4905346648508934), 'f1_samples': np.float64(0.8277148950131233), 'hamming_loss': 0.026033464566929135, 'auroc_micro': np.float64(0.9900282797505745), 'auroc_macro': np.float64(0.9048405377442373), 'ap_micro': np.float64(0.9419798919994129), 'ap_macro': np.float64(0.5591721002565273), 'used_argmax_multiclass': False}

# %% [markdown]
# **class balancing optimization**
# - trim: we can tune the maximum weight ratio

# %%
pos = y_tr_bin.sum(axis=0).astype(float)
neg = (y_tr_bin.shape[0] - pos).astype(float)

ratio = np.where(pos > 0, neg / pos, np.nan)

spw_global = float(np.nanmedian(ratio))

trim_ = False
if trim_:
    spw_global = float(np.clip(spw_global, 1.0, 50.0))

print("global scale_pos_weight =", spw_global)
# Out:
# global scale_pos_weight = 390.4028159340659

# %%
xgb_params = {
    "objective": "binary:logistic",
    "tree_method": "hist",
    "device": "cuda",
    "n_estimators": n_estimators,
    "learning_rate": learning_rate,
    "max_depth": max_depth,
    "subsample": subsample,
    "colsample_bytree": colsample_bytree,
    "reg_lambda": reg_lambda,

    "max_delta_step" : 1,
    "scale_pos_weight" : spw_global,

    "n_jobs": n_jobs,
    "random_state": TTS_SEED,
}

# %%
xgb_base = xgb.XGBClassifier(**xgb_params)
model = OneVsRestClassifier(xgb_base, n_jobs=1)

xgb_pipeline = Pipeline([
    ('preprocess', ct),
    ('model', model)
])

# %%
# raw
xgb_raw = clone(xgb_pipeline)
xgb_raw.fit(X_tr_0, y_tr_bin)

P_val_raw = xgb_raw.predict_proba(X_val_0)
xgb_res_raw = score_overall_and_rc(
    y_val_bin, P_val_raw, mlb,
    split_name="xgb-ovr-val-raw",
    threshold=0.5,
    inputs_are_probs=True,
)

# bandpass
xgb_filt = clone(xgb_pipeline)
xgb_filt.fit(X_tr_1, y_tr_bin)

P_val_filt = xgb_filt.predict_proba(X_val_1)
xgb_res_filt = score_overall_and_rc(
    y_val_bin, P_val_filt, mlb,
    split_name="xgb-ovr-val-filt",
    threshold=0.5,
    inputs_are_probs=True,
)
# Out:
# [xgb-ovr-val-raw] overall: {'f1_micro': np.float64(0.5364812153561896), 'f1_macro': np.float64(0.1877266369527083), 'f1_samples': np.float64(0.6017468807953408), 'hamming_loss': 0.02955111827776847, 'auroc_micro': np.float64(0.9750981218348219), 'auroc_macro': np.float64(0.8611330033406326), 'ap_micro': np.float64(0.7422659163541758), 'ap_macro': np.float64(0.24935095966796758)}
# [xgb-ovr-val-raw] conditions: {'f1_micro': np.float64(0.3650947310192228), 'f1_macro': np.float64(0.15110888494488434), 'f1_samples': np.float64(0.22454657680529036), 'hamming_loss': 0.026897028496437946, 'auroc_micro': np.float64(0.9577989063354275), 'auroc_macro': np.float64(0.8590323320944482), 'ap_micro': np.float64(0.42662497308093533), 'ap_macro': np.float64(0.20728794434487452)}
# [xgb-ovr-val-raw] rhythm: {'f1_micro': np.float64(0.7870211260487213), 'f1_macro': np.float64(0.49531575381842946), 'f1_samples': np.float64(0.8238927165354332), 'hamming_loss': 0.05184547244094488, 'auroc_micro': np.float64(0.9895089323240652), 'auroc_macro': np.float64(0.8760477691885423), 'ap_micro': np.float64(0.940943720593735), 'ap_macro': np.float64(0.5479983684619285), 'used_argmax_multiclass': False}
# [xgb-ovr-val-filt] overall: {'f1_micro': np.float64(0.5325550805656034), 'f1_macro': np.float64(0.18828211455083307), 'f1_samples': np.float64(0.6111996787158024), 'hamming_loss': 0.029768386664432902, 'auroc_micro': np.float64(0.9749038170076915), 'auroc_macro': np.float64(0.8826538402614091), 'ap_micro': np.float64(0.7371701346716368), 'ap_macro': np.float64(0.24847075154273274)}
# [xgb-ovr-val-filt] conditions: {'f1_micro': np.float64(0.35918821239922155), 'f1_macro': np.float64(0.1511035363482148), 'f1_samples': np.float64(0.2207861734689838), 'hamming_loss': 0.027008342707161605, 'auroc_micro': np.float64(0.9573112211371482), 'auroc_macro': np.float64(0.8814455904788546), 'ap_micro': np.float64(0.4175106409490441), 'ap_macro': np.float64(0.20555026539980453)}
# [xgb-ovr-val-filt] rhythm: {'f1_micro': np.float64(0.7835010060362173), 'f1_macro': np.float64(0.5005821714528267), 'f1_samples': np.float64(0.8206282808398949), 'hamming_loss': 0.05295275590551181, 'auroc_micro': np.float64(0.989593672584078), 'auroc_macro': np.float64(0.8912324137175454), 'ap_micro': np.float64(0.938791232062758), 'ap_macro': np.float64(0.5532062031575227), 'used_argmax_multiclass': False}

# %% [markdown]
# worse performance -> interesting

# %% [markdown]
# class imbalance optimization -> per label weight vector

# %% [markdown]
# hyperparam tunning + CV on model pipeline:
# - https://xgboost.readthedocs.io/en/stable/tutorials/param_tuning.html

# %%
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold

# %%
n_estimators = 1000
max_depth = 8

learning_rate = 0.05
subsample = 0.8
colsample_bytree = 0.8
reg_lambda = 1

max_delta = 10

n_jobs = 10

# %%
xgb_params = {
    "objective": "binary:logistic",
    "tree_method": "hist",
    "device": "cuda",
    "n_estimators": n_estimators,
    "learning_rate": learning_rate,
    "max_depth": max_depth,
    "subsample": subsample,
    "colsample_bytree": colsample_bytree,
    "reg_lambda": reg_lambda,

    "max_delta_step" : max_delta,

    "n_jobs": n_jobs,
    "random_state": TTS_SEED,
}

# %%
xgb_base = xgb.XGBClassifier(**xgb_params)
model = OneVsRestClassifier(xgb_base, n_jobs=1)

xgb_pipeline = Pipeline([
    ('preprocess', ct),
    ('model', model)
])

# %% [markdown]
# dev sets (train/eval combination)

# %%
X_dev_0 = pd.concat((X_tr_0, X_val_0), axis=0, ignore_index=True)
X_dev_1 = pd.concat((X_tr_1, X_val_1), axis=0, ignore_index=True)
y_dev = np.concat((y_tr_bin, y_val_bin), axis=0)

assert X_dev_0.shape[0] == X_dev_1.shape[0] == y_dev.shape[0]

# %%
k = 5

# %%
cv = MultilabelStratifiedKFold(n_splits=k, shuffle=True, random_state=TTS_SEED)

# %%
def _ensure_2d_proba(P):
    """
    Make predict_proba output a (n_samples, n_labels) float array.
    (Some multioutput APIs return a list; this keeps code robust.)
    """
    if isinstance(P, list):
        cols = []
        for p in P:
            cols.append(p[:, 1] if p.ndim == 2 and p.shape[1] == 2 else np.ravel(p))
        return np.column_stack(cols)
    return np.asarray(P)


def run_cv_ap(X_dev, y_dev, *, split_name, pipeline, mlb, threshold=0.5):
    n, L = X_dev.shape[0], y_dev.shape[1]
    oof_P = np.zeros((n, L), dtype=float)
    rows = []

    for fold, (tr_idx, va_idx) in enumerate(cv.split(X_dev, y_dev), start=1):
        est = clone(pipeline)
        est.fit(X_dev.iloc[tr_idx], y_dev[tr_idx])

        P = _ensure_2d_proba(est.predict_proba(X_dev.iloc[va_idx]))
        oof_P[va_idx] = P

        ap_micro = average_precision_score(y_dev[va_idx], P, average="micro")
        ap_macro = average_precision_score(y_dev[va_idx], P, average="macro")

        rows.append({"split": split_name, "fold": fold, "ap_micro": ap_micro, "ap_macro": ap_macro})


    df = pd.DataFrame(rows)
    summary = df[["ap_micro", "ap_macro"]].agg(["mean", "std"]).T
    return df, summary, oof_P

# %%
# raw
raw_folds, raw_summary, raw_oofP = run_cv_ap(
    X_dev_0, y_dev, split_name="xgb-cv-dev-raw",
    pipeline=xgb_pipeline, mlb=mlb, threshold=0.5
)

# bandpass
filt_folds, filt_summary, filt_oofP = run_cv_ap(
    X_dev_1, y_dev, split_name="xgb-cv-dev-filt",
    pipeline=xgb_pipeline, mlb=mlb, threshold=0.5
)

print("RAW CV AP:\n", raw_summary)
print("\nFILT CV AP:\n", filt_summary)


_ = score_overall_and_rc(y_dev, raw_oofP,  mlb, split_name="xgb-cv-dev-raw-OOF",  threshold=0.5, inputs_are_probs=True)
_ = score_overall_and_rc(y_dev, filt_oofP, mlb, split_name="xgb-cv-dev-filt-OOF", threshold=0.5, inputs_are_probs=True)
# Out:
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\multiclass.py:90: UserWarning: Label not 26 is present in all training examples.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\multiclass.py:90: UserWarning: Label not 92 is present in all training examples.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\multiclass.py:90: UserWarning: Label not 26 is present in all training examples.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\multiclass.py:90: UserWarning: Label not 92 is present in all training examples.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# c:\Users\samue\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_ranking.py:1030: UserWarning: No positive class found in y_true, recall is set to one for all thresholds.
#   warnings.warn(
# RAW CV AP:
#               mean       std
# ap_micro  0.75212  0.001366
# ap_macro  0.21475  0.006761
#
# FILT CV AP:
#                mean       std
# ap_micro  0.750369  0.001930
# ap_macro  0.218884  0.004148
# [xgb-cv-dev-raw-OOF] overall: {'f1_micro': np.float64(0.659815941447145), 'f1_macro': np.float64(0.13223848115278394), 'f1_samples': np.float64(0.7245636802916421), 'hamming_loss': 0.011535774987721214, 'auroc_micro': np.float64(0.979529276463843), 'auroc_macro': np.float64(0.8436824046837216), 'ap_micro': np.float64(0.752098088573102), 'ap_macro': np.float64(0.20166379379481184)}
# [xgb-cv-dev-raw-OOF] conditions: {'f1_micro': np.float64(0.32801161103047893), 'f1_macro': np.float64(0.08965102397437406), 'f1_samples': np.float64(0.1359401523918923), 'hamming_loss': 0.009902275129670906, 'auroc_micro': np.float64(0.9650273830960866), 'auroc_macro': np.float64(0.840886604772429), 'ap_micro': np.float64(0.4410628701731858), 'ap_macro': np.float64(0.16085230604236994)}
# [xgb-cv-dev-raw-OOF] rhythm: {'f1_micro': np.float64(0.8704608277481162), 'f1_macro': np.float64(0.489973121451427), 'f1_samples': np.float64(0.8339715509179505), 'hamming_loss': 0.025257173795343802, 'auroc_micro': np.float64(0.9909173947038342), 'auroc_macro': np.float64(0.8671671239385788), 'ap_micro': np.float64(0.9454215227720066), 'ap_macro': np.float64(0.5444802909153237), 'used_argmax_multiclass': False}
# [xgb-cv-dev-filt-OOF] overall: {'f1_micro': np.float64(0.6573777839600624), 'f1_macro': np.float64(0.1344439404742077), 'f1_samples': np.float64(0.7235598717645771), 'hamming_loss': 0.011607510323081289, 'auroc_micro': np.float64(0.9797613169117758), 'auroc_macro': np.float64(0.8515067706004846), 'ap_micro': np.float64(0.7503608049538988), 'ap_macro': np.float64(0.2041619603315617)}
# [xgb-cv-dev-filt-OOF] conditions: {'f1_micro': np.float64(0.322531847133758), 'f1_macro': np.float64(0.09204854254536471), 'f1_samples': np.float64(0.13573478333777592), 'hamming_loss': 0.009971710296561407, 'auroc_micro': np.float64(0.9657290477184908), 'auroc_macro': np.float64(0.8496501502199058), 'ap_micro': np.float64(0.43666795493461447), 'ap_macro': np.float64(0.16329081337481668)}
# [xgb-cv-dev-filt-OOF] rhythm: {'f1_micro': np.float64(0.8698870670271089), 'f1_macro': np.float64(0.49056528307648894), 'f1_samples': np.float64(0.833042115797936), 'hamming_loss': 0.025348230545848303, 'auroc_micro': np.float64(0.9905825170769006), 'auroc_macro': np.float64(0.867102381797347), 'ap_micro': np.float64(0.9441099607334541), 'ap_macro': np.float64(0.5474795947682198), 'used_argmax_multiclass': False}

# %% [markdown]
# results:
# - average AP:
#     raw:
#         - micro: mean = 0.75212, std = 0.001366
#         - macro: mean = 0.21475, std = 0.006761
#
#     filter:
#         - micro: mean = 0.750369, std = 0.001930
#         - macro: mean = 0.218884, std = 0.004148
# - average F1:

# %% [markdown]
# re-fit on all data (train + val)

# %%
run_ = False
save_ = True

# %%
if run_:
    # raw (train on dev, evaluate on test)
    xgb_raw = clone(xgb_pipeline)
    xgb_raw.fit(X_dev_0, y_dev)

    P_test_raw = xgb_raw.predict_proba(X_test_0)
    xgb_res_raw = score_overall_and_rc(
        y_test_bin, P_test_raw, mlb,
        split_name="xgb-final-test-raw",
        threshold=0.5,
        inputs_are_probs=True,
    )

    # bandpass (train on dev, evaluate on test)
    xgb_filt = clone(xgb_pipeline)
    xgb_filt.fit(X_dev_1, y_dev)

    P_test_filt = xgb_filt.predict_proba(X_test_1)
    xgb_res_filt = score_overall_and_rc(
        y_test_bin, P_test_filt, mlb,
        split_name="xgb-final-test-filt",
        threshold=0.5,
        inputs_are_probs=True,
    )

    if save_:
        joblib.dump(xgb_raw, '../models/xgb/xgb-final-raw.joblib')
        joblib.dump(xgb_filt, '../models/xgb/xgb-final-filt.joblib')

# %% [markdown]
# ### **Post-processing**

# %% [markdown]
# #### Metric scoring
#
# Main metrics:
# - Rank based:
#     - Average Precision (AP) -> sumarizes precision-recall curve -> good for imbalanced data
#
# - Treshold based:
#     - f1 micro
#     - f1 macro

# %% [markdown]
# #### Scoring system
#
# - Multilabel decomposition:
#     - rhytm snomed CT codes evaluation (single label)
#     - conditions snomed CT codes evaluation (multi label)
#
# - Evaluation analysis:
#     - best/worst performing rhytms
#     - best/worst performing conditions
#     - rare labels performance
#
# - treshold tunning:
#     - post processing on treshold based metrics
#     - we evaluate on ranking metrics and then determine the best tresholds

# %% [markdown]
# ##### Parameter importance analysis

# %% [markdown]
# ___
# #### Testing hold-out set
# - running final model + baseline once on the test set

# %% [markdown]
# baseline

# %% [markdown]
# final optimized model

# %% [markdown]
# ___
# #### **DL (Deep Learning)**

# %% [markdown]
# pytorch installation test + GPU support check

# %%
import torch

# %%
x = torch.rand(5, 3)
print(x)

cuda = torch.cuda.is_available()
print(cuda)
if cuda:
    print("cuda device count:", torch.cuda.device_count())
    print("cuda device name:", torch.cuda.get_device_name())
# Out:
# tensor([[0.6856, 0.1604, 0.8489],
#         [0.8753, 0.4726, 0.5957],
#         [0.9645, 0.2421, 0.3777],
#         [0.2628, 0.0031, 0.7061],
#         [0.7295, 0.6117, 0.3450]])
# True
# cuda device count: 1
# cuda device name: NVIDIA GeForce RTX 3060 Laptop GPU

# %% [markdown]
# DL preprocessing
# - we will pass raw ECG signals mapped per row (instead of calculating features as in ML pipe)

# %% [markdown]
# ___
# #### xAI: Model Explainability
# ideas:
# - integrated gradients
# - knowledge distillation: DL -> ML
